# %%
# %matplotlib inline

import json

import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 30)

# set some nicer defaults for matplotlib
from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = False
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecessary plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %% [markdown]
# # Classification

# %% [markdown]
# ## Based on "type" of 311 reports

# %% [markdown]
# <b>Overview and Motivation</b>

# %% [raw]
# **The focus of the analysis included trying to understand:**
#
# Is it possible to build a classifier to classify the unstructured description and summary fields into specific categories (i.e. pothole/paving, traffic, signage)?**  We used supervised learning to conduct the analysis and first manually classified the complete dataset, then tested it using a training / test set.  The application would be for a City 311 platform that brings in lots of unstructured data and needs a way to classify it for analysis and action.

# %% [raw]
# These probabilities were determined using the Bayesian model, the Naive Bayes classifier.

# %% [raw]
# Content:
# ------------------
# - Related Work
# - Data
# - Create "bags of words"  and coded classes used for cross-validation and and as training set
# - Cross Validation
# - Build the Classifier
# - Model Calibration
# - Interpretation of Result
#     - 10 most predict words
#     - 10 least predictive words
#     - 5 summary+description where model performs worst
#     - 5 summary+description where model performs well
# - Summary

# %% [markdown]
# <b>Related Work</b>

# %% [raw]
# The work in this section is similar to the sentiment analysis in CS109 Homework 3, the "Bayesian Tomatoes". In the homework, a Naive Bayes classifier was used to build a prediction model for whether a review is fresh or rotten, depending on the text of the review.
# In a similar approach, this work used a Naive Bayes classifies to build a prediction model for whether a concantenated 'description' and 'summary' of a request is related to the request is related pothole/paving, traffic, signage, etc.

# %% [markdown]
# <b>Data</b>

# %% [raw]
# The first step is to load the data conataining 311 reports that we have already downloaded and cleaned.

# %%
#Load 311 data
data = pd.read_csv(".\SeeClickFixData_Primary.csv")

# %%
# We dropped rows containing "nan, FALSE, Mail" from the dataframe. This is beacuase nan and FALSE are 
# not helpful and meaninful respectively. And there are only two 'Mail' types, which is two few to use classification.
data = data[~data.type.isnull()]
data = data[data.type != 'none']
data = data[data.type != 'FALSE']
data = data[data.type != 'Mail']
data = data[data.type.str.len() > 0]

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                            address                  bitly            created_at                                        description      id  issue_id        lat        lng  minutes_since_created  page  rating  request_type_id                                        slug status                                 summary            updated_at             updated_at_raw  user_id  vote_count     type neighborhood         city type_large  closed_dummy
# 4           4             4  520 Country Club Drive Stockbridge, GA 30281, USA  http://bit.ly/1f6n9b0  12/07/2013 - 09:49am                      Stop sign street sigh missing  846733    846733  33.517456 -84.218910                    288     1       2             3963  846733-traffic-signals-street-lights-signs   Open  Traffic Signals, Street Lights & Signs  12/07/2013 - 11:21am  2013-12-07T11:21:46-05:00   135598           1  Traffic               Stockbridge    Traffic             0
# 5           5             5  Redbud Lane And Country Club Drive In Windsong...  http://bit.ly/1f6h4Lu  12/07/2013 - 09:09am   Stop sign knocked down and missing on Redbud ...  846718    846718  32.157435 -82.907123                    327     1       1                0        846718-sign-knocked-down-and-missing   Open           Sign knocked down and missing  12/07/2013 - 09:09am  2013-12-07T09:09:44-05:00      NaN           0  Signage                              Signage             0
# 6           6             6  1275 Eagles Landing Parkway Stockbridge, GA 30...  http://bit.ly/13CU4QM  12/07/2013 - 09:05am                                                NaN  846717    846717  33.506439 -84.228508                    331     1       1             3958                       846717-sign-violation   Open                          Sign Violation  12/07/2013 - 09:05am  2013-12-07T09:05:48-05:00   135598           0  Signage               Stockbridge    Signage             0
# 7           7             7  1275 Eagles Landing Parkway Stockbridge, GA 30...  http://bit.ly/13CU2II  12/07/2013 - 09:05am                                            2 signs  846716    846716  33.506729 -84.228294                    332     1       1             3958                       846716-sign-violation   Open                          Sign Violation  12/07/2013 - 09:05am  2013-12-07T09:05:12-05:00   135598           0  Signage               Stockbridge    Signage             0
# 8           8             8  460-470 Old Atlanta Road Stockbridge, GA 30281...  http://bit.ly/13CU2s6  12/07/2013 - 09:04am                                                NaN  846715    846715  33.550491 -84.257774                    333     1       1             3958                       846715-sign-violation   Open                          Sign Violation  12/07/2013 - 09:04am  2013-12-07T09:04:08-05:00   135598           0  Signage               Stockbridge    Signage             0

# %%
# A function that select the unique values in 'status' column, which will be  classification
def getUnique(dataframe,col):
    return dataframe[col].unique()

# %%
# The classes are then stored in a variable
classes = getUnique(data,'type')

# %%
# So, what classes do we have?
print 'Code ', 'Class'
print '--------------'
for c in classes:
    print list(classes).index(c),'-->',c
# Out:
# Code  Class
# --------------
# 0 --> Traffic
# 1 --> Signage
# 2 --> Dumping/debris
# 3 --> Garbage
# 4 --> Street cleaning
# 5 --> Utilities
# 6 --> Street lighting
# 7 --> Pothole/paving
# 8 --> Animal
# 9 --> Overgrowth
# 10 --> Tree
# 11 --> Lane markings
# 12 --> Billing
# 13 --> Water/sewage system
# 14 --> Other
# 15 --> Code violation
# 16 --> Parking
# 17 --> Vacant/Delapidated
# 18 --> Illegal activity
# 19 --> Sidewalk
# 20 --> Parks
# 21 --> Nuisance
# 22 --> Illegal sign
# 23 --> Ditch cleaning
# 24 --> Fire hydrant
# 25 --> Crosswalk
# 26 --> Bicycle
# 27 --> Homeless

# %% [raw]
# In order to improve the accuracy of our classification, we merged the summary and the description columns:

# %%
# Add description and summary columns
data['sum_desc'] = data['summary']+' '+data['description']
data['sum_desc'] = data['sum_desc'].fillna('')

# %% [markdown]
# ### Create "bag of words" and coded classes to be used in cross validation and to train classifier

# %% [raw]
# Because our model will be built using a Naive Bayes Classifier, we need to convert 'sum_desc' to bags of vector. This can be achieved using sklearn CountVectorizer.
# As required by the clasifier, each of the class names was coded as a number, which is the same as its index in the 'classes' array above.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# function to return index of the classes as the class numeric value
def status(val):
    return list(classes).index(val)

# funtion to return bags-of-words and a numpy array representing the numeric classes codes
def make_xy(data, vectorizer=None):     
    y = data.type.apply(status) 
    if vectorizer == None:
        vectorizer = CountVectorizer(min_df=0) #initialize vectorizer     
    vectorizer.fit(data.sum_desc) 
    x = vectorizer.transform(data.sum_desc) #create bag of words 
    return x.tocsc(), y

# %%
# To be used latter to calculate loglikehood in the log_likelihood function,
# we retrieve indices, which are values representing stored classes

indices = [list(classes).index(val) for val in classes]

# %% [markdown]
# ### Cross Validation

# %%
# A loglikelihood function to help determine the min_df and alpha for vectorization and classification 
# respecively in the cross validation procedure

def log_likelihood(clf,x,y):
    result = 0    
    X_log_proba = clf.predict_log_proba(x)
    df = pd.DataFrame(X_log_proba)    
    
    for i in range(0, len(y)):
        for index in indices:
            if (y[i] == index):
                if index < df.shape[1]:
                    result += df[index][i]   
            
    return result

# %% [raw]
# This function return a the cross validation score using a scoring function (i.e. the log_likelihood function), the classifier (clf), the bag of woords (X), and the classes (Y)
# The data "bags of words" and the classes were folded 10 times to improve our chances of getting the right mi_df and alpha for our model

# %%
from sklearn.cross_validation import KFold
# a function to return average score by folding the training and test set 10 times
def cv_score(clf, x, y, score_func):
    result = 0
    nfold = 10 #number of folds
    for train, test in KFold(y.size, nfold): # split data into train/test groups, 10 times
        clf.fit(x[train], y[train]) # fit
        result += score_func(clf, x[test], y[test]) # evaluate score function on held-out data
    return result / nfold # average

# %% [raw]
# This section loops through a set of alpha, and min_dfs to determine the best alpha and min_df for our classification model.
# - alpha is smoothning factor, a Naive Bayes Classifier parameter, that determines the sensitivity to any single feature
# - min_df is the CountVectorizer keyword, which help it to ignore words that appears fewer than min_df fraction of the 311 descriptions

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB

# the list of alpha and min_dfs to test to hel determine the best alpha and min_df, using cross-validation

alphas = [0, .1, 1, 5, 10, 50,70,100,120,150,200,300,400,500]
min_dfs = [0,1e-1,1e-2,1e-3, 1e-4, 1e-3, 1e-2, 1e-1]

#Find the best value for alpha and min_df, and the best classifier
best_alpha = None
best_min_df = None
max_loglike = -np.inf
for alpha in alphas:
    for min_df in min_dfs:  
        # charset_error was ingnored due to situations where description contains non english or 
        # understandable chracters
        vectorizer = CountVectorizer(min_df = min_df,token_pattern=u'(?u)\\b\\w{3,}\\w+\\b',charset_error='ignore')       
        X, Y = make_xy(data, vectorizer)
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y)
        clf = MultinomialNB(alpha=alpha)
        clf.fit(X_train, Y_train)
        score = cv_score(clf, X_test, Y_test, log_likelihood)   
        # store new best values if score greater than previous log like value 
        if score > max_loglike:
            max_loglike = score
            best_alpha = alpha
            best_min_df = min_df

# %%
# Print the best alpha and best min_df
print "alpha: %f" % best_alpha
print "min_df: %f" % best_min_df
# Out:
# alpha: 10.000000
# min_df: 0.010000

# %% [raw]
# Now, based on our best alpha and min_df, we are going to create a classification model

# %% [markdown]
# ### Build the Classifier

# %%
#Create a new classifier and a new vetorizer based on the best alpha and min_df
vectorizer = CountVectorizer(min_df=best_min_df,token_pattern=u'(?u)\\b\\w{3,}\\w+\\b',charset_error='ignore')
X, Y = make_xy(data,vectorizer)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5)
clf = MultinomialNB(alpha=best_alpha)
clf.fit(X_train, Y_train)
accr_train = clf.score (X_train,Y_train)
accr_test = clf.score (X_test,Y_test)
#check the accuracy of the result
print "training accuracy: " + str (accr_train)
print "test accuracy: " + str (accr_test)
# Out:
# training accuracy: 0.798312575331
# test accuracy: 0.762153475291

# %% [raw]
# Since the accuracy of test set is less than the accuracy of training set, our model is not overfiting.

# %% [markdown]
# ### Calibration

# %% [raw]
# In this section we plot bar charts to see how good our model can predict each of our classes

# %%
prob_all = clf.predict_proba(X) 
df_all = pd.DataFrame(prob_all)
for ct in classes:
    if list(classes).index(ct) in df_all.columns:
        df_all[list(classes).index(ct)].hist(bins=20) # plot histogram for probability of incident closed distribution    
        plt.title('Histogram of Predicted Probability of '+ str(ct))
        plt.xlabel('P( '+str(ct)+' )')
        plt.ylabel('Number')
        plt.figure()   
        plt.show()

# %% [raw]
# 'Potholes/paving' and 'garbage' predictions are doing well, better than the rest of the classes, probably due to the fact that the number of description+summary pre-classified as potholes/paving and those pre-classified as garbage are more than the rest of the classes.

# %% [markdown]
# ### Interpretation

# %%
# Dataframe of probabilities
words = vectorizer.get_feature_names()
imatrix = np.eye(len(words))
probs = clf.predict_proba(imatrix)
df = pd.DataFrame(probs)
df['Word'] = words
#create classes for use as columns headers
col = {}
for ct in classes:
    col[list(classes).index(ct)]=ct
df.rename(columns=col, inplace=True)
df.head()
# Out:
#     Traffic   Signage  Dumping/debris   Garbage  Street cleaning  Utilities  Street lighting  Pothole/paving    Animal  Overgrowth      Tree  Lane markings   Billing  Water/sewage system     Other  Code violation   Parking  Vacant/Delapidated  Illegal activity  Sidewalk     Parks  Nuisance  Illegal sign  Ditch cleaning  Fire hydrant  Crosswalk   Bicycle       Word
# 0  0.024641  0.033052        0.067294  0.454649         0.018885   0.003356         0.015957        0.126763  0.004570    0.047617  0.027588       0.003972  0.023691             0.061633  0.000564        0.002150  0.002965            0.019336          0.004707  0.031020  0.003025  0.000564      0.002933        0.005263      0.001116   0.001612  0.011077       2013
# 1  0.055371  0.074271        0.084682  0.120194         0.019289   0.007541         0.039443        0.113941  0.008558    0.053501  0.041329       0.008926  0.017746             0.055399  0.001268        0.004392  0.007328            0.159315          0.010578  0.063368  0.006797  0.001267      0.006590        0.007884      0.002508   0.003623  0.024891  abandoned
# 2  0.072002  0.060997        0.062096  0.090487         0.014522   0.005161         0.039265        0.311924  0.007614    0.043939  0.039600       0.006109  0.012145             0.083413  0.000868        0.003006  0.005472            0.039649          0.007239  0.056380  0.005117  0.000867      0.004961        0.005936      0.001717   0.002479  0.017035      about
# 3  0.053918  0.066294        0.073624  0.107285         0.015652   0.006119         0.032006        0.268128  0.007639    0.043413  0.060367       0.007243  0.014400             0.071926  0.001029        0.003564  0.005406            0.047010          0.008583  0.061704  0.005515  0.001028      0.005348        0.007038      0.002035   0.003528  0.020198     across
# 4  0.078822  0.070484        0.047836  0.199614         0.018306   0.005963         0.028357        0.225273  0.006768    0.046542  0.032685       0.008471  0.014034             0.056955  0.001003        0.003474  0.005269            0.031498          0.008365  0.065148  0.005375  0.001002      0.005733        0.006235      0.001984   0.003152  0.021653      after

# %% [markdown]
# #### Here, we print out the 10 most predictive words for each of the classes:

# %%
# 10 most predictive words
for ct in classes:
    if ct in df.columns:        
        print "10 most predictive word for : " + str(ct)
        print "------------------------------------"  
        r = df.sort(ct,ascending=False)
        wrd = r.head(10)
        print wrd[[ct,'Word']]
        print "====================================="
# Out:
# 10 most predictive word for : Traffic
# ------------------------------------
#       Traffic          Word
# 209  0.505802        signal
# 242  0.492030       traffic
# 124  0.373354         light
# 248  0.268337          turn
# 217  0.246371         speed
# 96   0.237340         green
# 112  0.193848  intersection
# 123  0.190125          left
# 165  0.164920    pedestrian
# 33   0.160746          cars
# =====================================
# 10 most predictive word for : Signage
# ------------------------------------
#       Signage     Word
# 208  0.748512     sign
# 143  0.562515     name
# 198  0.516521    round
# 174  0.508846     post
# 133  0.487603     make
# 12   0.459320  atlanta
# 126  0.424910     like
# 191  0.393683  request
# 173  0.372896     pole
# 172  0.358435   please
# =====================================
# 10 most predictive word for : Dumping/debris
# ------------------------------------
#      Dumping/debris       Word
# 65         0.411441     debris
# 169        0.272185       pile
# 127        0.248111      limbs
# 13         0.221409       attn
# 111        0.218604  inspector
# 243        0.213198      trash
# 252        0.199756     vacant
# 110        0.179244    illegal
# 274        0.156928       yard
# 179        0.143537   property
# =====================================
# 10 most predictive word for : Garbage
# ------------------------------------
#       Garbage         Word
# 34   0.921879         cart
# 92   0.894683      garbage
# 192  0.715033   requesting
# 188  0.657717  replacement
# 193  0.619150    residence
# 202  0.610162      service
# 219  0.572595       stolen
# 32   0.529933       broken
# 194  0.529163     resident
# 63   0.472911         date
# =====================================
# 10 most predictive word for : Street cleaning
# ------------------------------------
#      Street cleaning       Word
# 5           0.045670      alley
# 43          0.040613   cleaning
# 42          0.028463    cleaned
# 258         0.025562  wednesday
# 41          0.025342      clean
# 7           0.024604      along
# 128         0.024264       line
# 206         0.023669      sides
# 227         0.023106     thanks
# 80          0.023046     entire
# =====================================
# 10 most predictive word for : Utilities
# ------------------------------------
#      Utilities        Word
# 25    0.008363     billing
# 102   0.008270        high
# 173   0.007998        pole
# 128   0.007588        line
# 48    0.007587  completely
# 23    0.007573     bicycle
# 54    0.007544       creek
# 1     0.007541   abandoned
# 21    0.007457       being
# 110   0.007448     illegal
# =====================================
# 10 most predictive word for : Street lighting
# ------------------------------------
#      Street lighting      Word
# 124         0.156996     light
# 125         0.145972    lights
# 222         0.077237    street
# 151         0.070461     night
# 271         0.061290   working
# 173         0.058319      pole
# 83          0.050347     every
# 231         0.050100      then
# 56          0.050063  crossing
# 227         0.049559    thanks
# =====================================
# 10 most predictive word for : Pothole/paving
# ------------------------------------
#      Pothole/paving      Word
# 175        0.841559   pothole
# 176        0.799890  potholes
# 196        0.779429      road
# 105        0.710469      hole
# 163        0.629253  pavement
# 106        0.587264     holes
# 118        0.580352      lane
# 66         0.553235      deep
# 232        0.540206     there
# 120        0.519643     large
# =====================================
# 10 most predictive word for : Animal
# ------------------------------------
#        Animal       Word
# 64   0.014293       dead
# 25   0.009491    billing
# 168  0.009377     pickup
# 151  0.009249      night
# 141  0.009016    morning
# 26   0.008870      block
# 227  0.008674     thanks
# 239  0.008637      times
# 23   0.008595    bicycle
# 1    0.008558  abandoned
# =====================================
# 10 most predictive word for : Overgrowth
# ------------------------------------
#      Overgrowth         Word
# 157    0.307227    overgrown
# 95     0.236702        grass
# 59     0.193959      cutting
# 177    0.177644     premises
# 274    0.168813         yard
# 5      0.140744        alley
# 275    0.131821        yards
# 131    0.130956  maintenance
# 43     0.122439     cleaning
# 179    0.120276     property
# =====================================
# 10 most predictive word for : Tree
# ------------------------------------
#          Tree      Word
# 244  0.323061      tree
# 64   0.159854      dead
# 245  0.147757     trees
# 70   0.077548      down
# 127  0.076114     limbs
# 50   0.060417    corner
# 3    0.060367    across
# 184  0.055518   removed
# 26   0.054516     block
# 189  0.053633  reported
# =====================================
# 10 most predictive word for : Lane markings
# ------------------------------------
#      Lane markings     Word
# 119       0.020367    lanes
# 24        0.018647     bike
# 128       0.013474     line
# 153       0.013304     only
# 204       0.012613   should
# 160       0.012362  parking
# 118       0.011601     lane
# 167       0.010706   people
# 210       0.010643    signs
# 21        0.010593    being
# =====================================
# 10 most predictive word for : Billing
# ------------------------------------
#       Billing       Word
# 25   0.078722    billing
# 114  0.046333      issue
# 63   0.027604       date
# 0    0.023691       2013
# 23   0.017823    bicycle
# 1    0.017746  abandoned
# 102  0.017693       high
# 21   0.017549      being
# 110  0.017529    illegal
# 57   0.017513  crosswalk
# =====================================
# 10 most predictive word for : Water/sewage system
# ------------------------------------
#      Water/sewage system      Word
# 71              0.408139     drain
# 221             0.384172     storm
# 44              0.292385   clogged
# 35              0.254125     catch
# 16              0.254125     basin
# 257             0.235664     water
# 72              0.176811  drainage
# 53              0.169763     cover
# 42              0.108996   cleaned
# 43              0.106498  cleaning
# =====================================
# 10 most predictive word for : Other
# ------------------------------------
#         Other       Word
# 25   0.001407    billing
# 21   0.001380      being
# 115  0.001355     issues
# 23   0.001274    bicycle
# 1    0.001268  abandoned
# 102  0.001265       high
# 110  0.001253    illegal
# 57   0.001252  crosswalk
# 275  0.001250      yards
# 39   0.001249   children
# =====================================
# 10 most predictive word for : Code violation
# ------------------------------------
#      Code violation         Word
# 45         0.005620         code
# 25         0.004871      billing
# 131        0.004731  maintenance
# 253        0.004657      vehicle
# 75         0.004572     driveway
# 259        0.004468        weeks
# 48         0.004419   completely
# 23         0.004412      bicycle
# 1          0.004392    abandoned
# 102        0.004379         high
# =====================================
# 10 most predictive word for : Parking
# ------------------------------------
#       Parking       Word
# 160  0.011072    parking
# 45   0.009835       code
# 253  0.008348    vehicle
# 75   0.007565   driveway
# 25   0.007389    billing
# 201  0.007353    section
# 1    0.007328  abandoned
# 275  0.007223      yards
# 69   0.007182       done
# 246  0.007122     trucks
# =====================================
# 10 most predictive word for : Vacant/Delapidated
# ------------------------------------
#      Vacant/Delapidated       Word
# 252            0.159433     vacant
# 1              0.159315  abandoned
# 108            0.143003      house
# 274            0.119327       yard
# 190            0.102561    reports
# 177            0.096180   premises
# 179            0.090444   property
# 157            0.079576  overgrown
# 275            0.071371      yards
# 95             0.069903      grass
# =====================================
# 10 most predictive word for : Illegal activity
# ------------------------------------
#      Illegal activity          Word
# 25           0.011731       billing
# 160          0.011720       parking
# 45           0.011451          code
# 131          0.011392   maintenance
# 161          0.011296       parkway
# 148          0.011059  neighborhood
# 263          0.010935          what
# 96           0.010842         green
# 59           0.010816       cutting
# 81           0.010771      entrance
# =====================================
# 10 most predictive word for : Sidewalk
# ------------------------------------
#      Sidewalk         Word
# 207  0.525994     sidewalk
# 178  0.196820      problem
# 166  0.181293  pedestrians
# 256  0.178385         walk
# 137  0.133571      missing
# 165  0.129757   pedestrian
# 98   0.120413       hazard
# 55   0.112160        cross
# 167  0.109259       people
# 62   0.108614    dangerous
# =====================================
# 10 most predictive word for : Parks
# ------------------------------------
#         Parks        Word
# 159  0.008934        park
# 25   0.007538     billing
# 39   0.007364    children
# 199  0.007279        same
# 215  0.007074     someone
# 55   0.006965       cross
# 48   0.006838  completely
# 23   0.006826     bicycle
# 1    0.006797   abandoned
# 102  0.006776        high
# =====================================
# 10 most predictive word for : Nuisance
# ------------------------------------
#      Nuisance       Word
# 25   0.001405    billing
# 102  0.001390       high
# 45   0.001372       code
# 263  0.001310       what
# 43   0.001276   cleaning
# 23   0.001273    bicycle
# 1    0.001267  abandoned
# 21   0.001253      being
# 110  0.001252    illegal
# 57   0.001250  crosswalk
# =====================================
# 10 most predictive word for : Illegal sign
# ------------------------------------
#      Illegal sign     Word
# 110      0.018227  illegal
# 210      0.016924    signs
# 184      0.008220  removed
# 233      0.008006    these
# 253      0.007622  vehicle
# 25       0.007309  billing
# 45       0.007135     code
# 101      0.007066     here
# 199      0.007058     same
# 230      0.007055     them
# =====================================
# 10 most predictive word for : Ditch cleaning
# ------------------------------------
#      Ditch cleaning      Word
# 43         0.020931  cleaning
# 42         0.010858   cleaned
# 75         0.009698  driveway
# 138        0.009673    monday
# 229        0.009093     their
# 181        0.009033      rain
# 72         0.008881  drainage
# 25         0.008744   billing
# 129        0.008628   located
# 237        0.008325  thursday
# =====================================
# 10 most predictive word for : Fire hydrant
# ------------------------------------
#      Fire hydrant       Word
# 117      0.002878       know
# 25       0.002782    billing
# 142      0.002592       much
# 23       0.002519    bicycle
# 1        0.002508  abandoned
# 102      0.002501       high
# 225      0.002495       than
# 122      0.002494      least
# 21       0.002480      being
# 110      0.002478    illegal
# =====================================
# 10 most predictive word for : Crosswalk
# ------------------------------------
#      Crosswalk          Word
# 57    0.007508     crosswalk
# 55    0.004387         cross
# 166   0.004346   pedestrians
# 165   0.004046    pedestrian
# 25    0.004018       billing
# 102   0.003973          high
# 220   0.003811          stop
# 148   0.003788  neighborhood
# 271   0.003784       working
# 125   0.003766        lights
# =====================================
# 10 most predictive word for : Bicycle
# ------------------------------------
#       Bicycle     Word
# 23   0.132494  bicycle
# 24   0.070907     bike
# 98   0.062434   hazard
# 99   0.043264  hazards
# 119  0.031806    lanes
# 262  0.029591     west
# 101  0.028911     here
# 132  0.028179    major
# 26   0.028142    block
# 25   0.027605  billing
# =====================================

# %% [markdown]
# #### Here, we print out the 10 least predictive words for each of the classes:

# %%
# 10 least predictive words
for ct in classes:
     if ct in df.columns: 
        print "10 least predictive word for : " + str(ct)
        print "------------------------------------"
        r = df.sort(ct,ascending=True)
        wrd = r.head(10)
        print wrd[[ct,'Word']]
        print "====================================="
# Out:
# 10 least predictive word for : Traffic
# ------------------------------------
#       Traffic        Word
# 34   0.005940        cart
# 92   0.006637     garbage
# 175  0.012853     pothole
# 176  0.016015    potholes
# 192  0.016147  requesting
# 105  0.016441        hole
# 106  0.021356       holes
# 0    0.024641        2013
# 63   0.025333        date
# 194  0.025661    resident
# =====================================
# 10 least predictive word for : Signage
# ------------------------------------
#       Signage        Word
# 34   0.007967        cart
# 92   0.008902     garbage
# 175  0.015673     pothole
# 196  0.015704        road
# 176  0.019528    potholes
# 105  0.022053        hole
# 192  0.023824  requesting
# 32   0.024997      broken
# 235  0.025835        this
# 106  0.026041       holes
# =====================================
# 10 least predictive word for : Dumping/debris
# ------------------------------------
#      Dumping/debris      Word
# 34         0.006489      cart
# 196        0.011285      road
# 175        0.012764   pothole
# 176        0.015904  potholes
# 208        0.016127      sign
# 105        0.017960      hole
# 92         0.020301   garbage
# 106        0.021208     holes
# 242        0.021790   traffic
# 126        0.022794      like
# =====================================
# 10 least predictive word for : Garbage
# ------------------------------------
#       Garbage      Word
# 196  0.023919      road
# 175  0.025364   pothole
# 222  0.026329    street
# 176  0.031603  potholes
# 208  0.032046      sign
# 118  0.042221      lane
# 133  0.045878      make
# 242  0.046907   traffic
# 172  0.047770    please
# 126  0.049411      like
# =====================================
# 10 least predictive word for : Street cleaning
# ------------------------------------
#      Street cleaning      Word
# 34          0.002069      cart
# 92          0.002312   garbage
# 196         0.002639      road
# 175         0.004071   pothole
# 176         0.005072  potholes
# 232         0.005152     there
# 208         0.005657      sign
# 105         0.005727      hole
# 242         0.005791   traffic
# 90          0.005984      from
# =====================================
# 10 least predictive word for : Utilities
# ------------------------------------
#      Utilities      Word
# 34    0.000809      cart
# 92    0.000904   garbage
# 196   0.000938      road
# 175   0.001591   pothole
# 222   0.001652    street
# 232   0.001678     there
# 235   0.001749      this
# 176   0.001983  potholes
# 228   0.002000      that
# 208   0.002010      sign
# =====================================
# 10 least predictive word for : Street lighting
# ------------------------------------
#      Street lighting        Word
# 34          0.003846        cart
# 92          0.004298     garbage
# 175         0.007567     pothole
# 196         0.008028        road
# 176         0.009428    potholes
# 192         0.010457  requesting
# 105         0.010647        hole
# 208         0.011472        sign
# 106         0.012572       holes
# 118         0.012596        lane
# =====================================
# 10 least predictive word for : Pothole/paving
# ------------------------------------
#      Pothole/paving         Word
# 34         0.012223         cart
# 92         0.017755      garbage
# 192        0.033227   requesting
# 208        0.042530         sign
# 188        0.053290  replacement
# 193        0.057543    residence
# 219        0.066196       stolen
# 209        0.069388       signal
# 202        0.069410      service
# 143        0.069799         name
# =====================================
# 10 least predictive word for : Animal
# ------------------------------------
#        Animal      Word
# 34   0.000918      cart
# 92   0.001026   garbage
# 196  0.001597      road
# 222  0.001718    street
# 175  0.001806   pothole
# 235  0.002150      this
# 176  0.002250  potholes
# 228  0.002270      that
# 208  0.002282      sign
# 105  0.002541      hole
# =====================================
# 10 least predictive word for : Overgrowth
# ------------------------------------
#      Overgrowth      Word
# 34     0.005739      cart
# 92     0.006413   garbage
# 175    0.011290   pothole
# 176    0.014067  potholes
# 105    0.015886      hole
# 196    0.017966      road
# 32     0.018006    broken
# 208    0.018544      sign
# 106    0.018758     holes
# 126    0.021994      like
# =====================================
# 10 least predictive word for : Tree
# ------------------------------------
#          Tree        Word
# 34   0.004433        cart
# 92   0.004954     garbage
# 175  0.008722     pothole
# 176  0.010867    potholes
# 192  0.012052  requesting
# 208  0.012121        sign
# 105  0.012272        hole
# 106  0.014491       holes
# 191  0.014517     request
# 12   0.015491     atlanta
# =====================================
# 10 least predictive word for : Lane markings
# ------------------------------------
#      Lane markings        Word
# 34        0.000958        cart
# 92        0.001070     garbage
# 175       0.001884     pothole
# 196       0.002220        road
# 176       0.002347    potholes
# 192       0.002603  requesting
# 105       0.002650        hole
# 222       0.002770      street
# 191       0.002850     request
# 32        0.003004      broken
# =====================================
# 10 least predictive word for : Billing
# ------------------------------------
#       Billing      Word
# 34   0.001904      cart
# 196  0.002207      road
# 92   0.002340   garbage
# 222  0.003239    street
# 175  0.003745   pothole
# 235  0.003772      this
# 232  0.003950     there
# 176  0.004666  potholes
# 228  0.004706      that
# 208  0.004731      sign
# =====================================
# 10 least predictive word for : Water/sewage system
# ------------------------------------
#      Water/sewage system      Word
# 34              0.005943      cart
# 92              0.007304   garbage
# 175             0.012860   pothole
# 176             0.017479  potholes
# 208             0.019201      sign
# 106             0.019424     holes
# 12              0.020764   atlanta
# 126             0.022774      like
# 242             0.023283   traffic
# 196             0.023427      road
# =====================================
# 10 least predictive word for : Other
# ------------------------------------
#         Other      Word
# 34   0.000136      cart
# 92   0.000152   garbage
# 196  0.000158      road
# 222  0.000232    street
# 235  0.000245      this
# 175  0.000268   pothole
# 232  0.000282     there
# 176  0.000334  potholes
# 228  0.000336      that
# 208  0.000338      sign
# =====================================
# 10 least predictive word for : Code violation
# ------------------------------------
#      Code violation      Word
# 34         0.000471      cart
# 92         0.000527   garbage
# 196        0.000546      road
# 222        0.000882    street
# 175        0.000927   pothole
# 235        0.000934      this
# 176        0.001155  potholes
# 208        0.001171      sign
# 232        0.001173     there
# 90         0.001239      from
# =====================================
# 10 least predictive word for : Parking
# ------------------------------------
#       Parking        Word
# 34   0.000715        cart
# 92   0.000799     garbage
# 196  0.000994        road
# 175  0.001406     pothole
# 232  0.001631       there
# 176  0.001752    potholes
# 208  0.001776        sign
# 172  0.001891      please
# 192  0.001943  requesting
# 105  0.001978        hole
# =====================================
# 10 least predictive word for : Vacant/Delapidated
# ------------------------------------
#      Vacant/Delapidated      Word
# 34             0.003884      cart
# 92             0.004340   garbage
# 196            0.005854      road
# 175            0.007641   pothole
# 176            0.009520  potholes
# 208            0.009654      sign
# 105            0.010751      hole
# 242            0.011957   traffic
# 106            0.012695     holes
# 118            0.012719      lane
# =====================================
# 10 least predictive word for : Illegal activity
# ------------------------------------
#      Illegal activity      Word
# 34           0.001135      cart
# 92           0.001268   garbage
# 196          0.001447      road
# 175          0.002232   pothole
# 235          0.002453      this
# 222          0.002510    street
# 176          0.002781  potholes
# 228          0.002805      that
# 208          0.002820      sign
# 90           0.002983      from
# =====================================
# 10 least predictive word for : Sidewalk
# ------------------------------------
#      Sidewalk        Word
# 34   0.006798        cart
# 92   0.007596     garbage
# 175  0.013372     pothole
# 176  0.016661    potholes
# 192  0.018479  requesting
# 208  0.018585        sign
# 106  0.022218       holes
# 191  0.022258     request
# 133  0.024187        make
# 105  0.024460        hole
# =====================================
# 10 least predictive word for : Parks
# ------------------------------------
#         Parks        Word
# 34   0.000729        cart
# 92   0.000815     garbage
# 196  0.001014        road
# 222  0.001241      street
# 175  0.001434     pothole
# 232  0.001513       there
# 176  0.001787    potholes
# 208  0.001812        sign
# 192  0.001982  requesting
# 105  0.002018        hole
# =====================================
# 10 least predictive word for : Nuisance
# ------------------------------------
#      Nuisance      Word
# 34   0.000136      cart
# 92   0.000152   garbage
# 196  0.000158      road
# 222  0.000231    street
# 175  0.000267   pothole
# 235  0.000269      this
# 232  0.000282     there
# 176  0.000333  potholes
# 90   0.000357      from
# 172  0.000360    please
# =====================================
# 10 least predictive word for : Illegal sign
# ------------------------------------
#      Illegal sign        Word
# 34       0.000707        cart
# 92       0.000790     garbage
# 196      0.000984        road
# 175      0.001391     pothole
# 222      0.001444      street
# 176      0.001733    potholes
# 235      0.001783        this
# 192      0.001922  requesting
# 105      0.001957        hole
# 242      0.001978     traffic
# =====================================
# 10 least predictive word for : Ditch cleaning
# ------------------------------------
#      Ditch cleaning      Word
# 34         0.000846      cart
# 92         0.000945   garbage
# 196        0.000981      road
# 175        0.001664   pothole
# 235        0.001676      this
# 222        0.001727    street
# 232        0.001755     there
# 176        0.002073  potholes
# 208        0.002102      sign
# 105        0.002341      hole
# =====================================
# 10 least predictive word for : Fire hydrant
# ------------------------------------
#      Fire hydrant        Word
# 34       0.000269        cart
# 92       0.000301     garbage
# 196      0.000312        road
# 222      0.000458      street
# 232      0.000558       there
# 175      0.000582     pothole
# 176      0.000659    potholes
# 208      0.000669        sign
# 235      0.000679        this
# 192      0.000731  requesting
# =====================================
# 10 least predictive word for : Crosswalk
# ------------------------------------
#      Crosswalk        Word
# 34    0.000389        cart
# 92    0.000434     garbage
# 222   0.000661      street
# 196   0.000676        road
# 175   0.000765     pothole
# 235   0.000910        this
# 176   0.000953    potholes
# 172   0.001028      please
# 192   0.001056  requesting
# 208   0.001062        sign
# =====================================
# 10 least predictive word for : Bicycle
# ------------------------------------
#       Bicycle        Word
# 34   0.002670        cart
# 92   0.002984     garbage
# 196  0.005882        road
# 175  0.006303     pothole
# 222  0.006361      street
# 208  0.006636        sign
# 172  0.007066      please
# 232  0.007203       there
# 235  0.007215        this
# 192  0.007259  requesting
# =====================================

# %% [markdown]
# #### Here we print out summary+description from our dataset where our model performs worse.

# %%
# Where model performed poorly
probsX = clf.predict_proba(X)
df_probsX = pd.DataFrame(probsX)
for ct in classes:
     if ct in df.columns: 
        df_perf = pd.DataFrame({'Prob':df_probsX[list(classes).index(ct)],'SummaryDesc':data['sum_desc'], 'status':data['status'], 'Y':Y})
        df_perf = df_perf[df_perf.Y ==list(classes).index(ct)]
        
        df_perf = df_perf.sort(['Prob','SummaryDesc'],ascending=False)
        
        print "*** Worse prediction for " + str(ct) +" ***"
        print " "
        j = 1
        for i in df_perf[-5:]['SummaryDesc'].values:
            print str(j) + ". " + i
            j +=1
        print " "
# Out:
# *** Worse prediction for Traffic ***
#
# 1. Install Dead End or No Outlet Sign(s) GPS devices appear to be directing drivers to use Ridgeview Road as a rush hour short cut. This road terminates in a dead end but drivers are then trespassing through two private parking areas including both a private drive and an apartment parking garage to reach Ashwood Parkway and ultimately Ashford Dunwoody.
# 2. Heavy traffic and young drivers Now that East Lake Rd connects I-75 to other heavily populated areas in Henry County, the rush hour traffic that passes UGHS is very heavy at the same time these young drivers are completing their after-school activities.  There needs to be a crossing guard there until 6:30 every school day.  One is needed at Bryan's Dr. and in front of high school.
# stevensanders@tfc.edu
# 4. Reinstall left turn signal Coming out of Publix without a left turn signal has become a seriously dangerous issue.  People are so desperate to make the left onto Chamblee-Dunwoody that they are making the turn in front of traffic coming the other way, that has the right-of-way.  I was almost hit by four vehicles in a row that made the left turn in front of me, while I was trying to make the right turn, with the right-of-way.
# 5. traffic light timer vehicle immediately trips traffic light , stopping traffic on Highway 21. takes forever for traffic light to change with no vehicles going through intersection
#
# *** Worse prediction for Signage ***
#
# Name Sign On MLK Jr Dr. & Hamilton E. Holmes Dr. In SW Atlanta Please?
# In SW Atlanta Please?
# 3. Missing Street sign Need street sign replaced as Homeplace Dr and Speer Road
# 4. Missing Stop Sign A new stop sign was installed facing eastbound on the southwest corner of Highland Ave and Sampson Street.  This new sign was installed (per the Commuter Dude) so the westbound Highland Ave drivers would know to stop.  The stop sign fell or was knocked down and a new one needs to be installed.
# 5. Street Name Sign I Like To Make A Request On A Street Name Sign On Ponce De Leon Ave & Bonaventure Ave In NE Atlanta Please?
#
# *** Worse prediction for Dumping/debris ***
#
# 1. Illegal Dumping of tires and wood There are many tires that have been dumped behind a shopping center near  Lawrenceville Highway North Druid Hills Road, across from Shamrock Plaza.  The tires seem to be multiplying.  The owner also needs to cut the more than 2 feet high of grass near the vacant emissions station in the front of this plaza as well.
# 2. DEBRIS Neighbor has moved and left Debris in front of property by the Curb. Trash is flying into other neighbors property.
# 3. Debris / Medium Pile MEDIUM PILE OF YARD CLIPPINGS
# 4. Debris / Limbs / yard trimmings / 4 weeks out LIMBS AND YARD TRIMMINGS
# DATE:  5-31-2013 (FRIDAY)
#
# *** Worse prediction for Garbage ***
#
# DATE:  8-09-2013 (FRIDAY)
# 2. Garbage Cart / New Residence New service, requesting a garbage cart.
# 3. Garbage Cart / Missing bar NO BAR, AND NO LID
# 4. wheel broken Garbage cart wheel appears to have been broken after todays pickup.
# 5. Garbage Cart / New Residence New service, requesting a garbage cart.
#
# *** Worse prediction for Street cleaning ***
#
# DATE:  8-08-2013 (THURSDAY)
# 2. Alley needs cleaning Alley between 1084- 1094 @ Harvey Ave
# Litter - Trash on the right of way on Miller Rd. near Neal Ave.
# DATE:  10-17-2013 (THURSDAY)
# ADVISED 520 @ 12:58 P.M.
#
# *** Worse prediction for Utilities ***
#
# 1. Support lines on AT&T Power Pole Down There are 3 LONG galvanized support wires that are down and hanging from a pole in front of my subdivision, The Preserve at Fischer Mansion. You can't miss them. I have contacted AT&T several times with no luck on getting them fixed. It appears the wires were support lines to brace a pole from across the street. The pole was replaced and the wires are now laying on our property. Even worse, there were teenagers swinging from the wires last week. These wires are actually touching the main power lines and in my opinion, a major safety hazard. The pole in question is actually on Chamblee Dunwoody Road, Brookhaven side, in front of our subdivision. There is no actual address to give other than that.
# 2. Utility line in street Utility line in street
# 3. Utility line on ground Utility line on ground
# 4. broken water meter lid  broken water meter lid in front of entrance to restaurant = hazard and dangerous situation
# 5. Split power/phone pole One of the power poles on the corner of this property (1480 briarcliff rd ne) is split/broken/damaged and needs to be replaced before it collapses completely.
#
# *** Worse prediction for Street lighting ***
#
# 1. street light out  street light still out at Tupelo Trail & Parkbrooke Way. Pole # 15
# 2. Street Lights Out Two street lights are out in Edgewood shopping center in the corner between pteco and Ross.
# 3. Streetlight Cracked light base. Jagged edge
# 4. Double Streetlight Behind Summergrove Sign Out This is a continuation of issue#670348.  The east bulb of the light pole behind the Summergrove sign at Sullivan Rd was never repaired.
# #7 - Both bulbs
#
# *** Worse prediction for Pothole/paving ***
#
# 1. ROAD NEEDS  RESURFACED NEED ROAD RESURFACED ON KLONDIKE FROM BLACKLAWN TO MCDANIEL MILL. SOME DAY THERE WILL BE AN ACCIDENT BECAUSE WE TRY TO AVOID THE EVER GROWING POTHOLES.  TIRED OF DODGING THEM AND SEEING FILLED HOLES OPENING UP AGAIN
# 2. Pot Hole  Between 4190 and 4188 Dunwoody Terrace a hole is appearing in pavement at juncture with kerb. Right above storm water sewer line. Hole now about 9 inches deep and is a void under tarmac. Small at surface.
# 3. 6x6 pothole - 6 to 8 inches deep Huge pothole on Paces Ferry where construction crew cut about a 6x6 hole. Gravel has washed out. NO SIGNS. We hit the hole at night. It was so hard it felt like it busted our tire. Hope it didn't bend the wheel.
# 4. Several Small Potholes This short block between North Ave NW and Spring St NW has many several mini potholes on the very right lane before going into I85-N. They have been here for months. Please fix them asap. Thanks.
# 5. Deep pothole Deep pothole in second from left lane
#
# *** Worse prediction for Animal ***
#
# 1. stray cats  the same stray cats have been reported for 6 years Animal control does not act to get rid of all of the breeders .They live in the storm drain system that drains into the city water supply
# 2. Rat Infestation Bldg 12000 & 9000 of the London Apts has rats. Complaints ave been made but no resolution.
# 3. Animal-Dead Pickup Request /1-total REQUEST PICKUP OF A DECEASED ANIMAL @ ON THE CURB IN FRONT OF BURGHARD ELEMENTARY SCHOOL.
# 4. animal abuse/antisanitary conditions on property Please investigate the back yard at 1176 Old Roswell Rd. There is a dog permanently living on the porch who goes to the bathroom right on the concrete, howls and whines. There are feces everywhere, flies, foul smell for months. The landlord is not doing anything about it, even though he was told about it many times. I am uploading an image. Thank you.
# 5. Animal-Dead Pickup Request /1-total Deceased animal in the road.
#
# *** Worse prediction for Overgrowth ***
#
# 1. Lot overgrown into street Vacant lot, severely overgrown, kudzu and weeds overtaking the street.
# 2. Grossly overgrown lots in our development are a hazard from rodents insects and snakes. These are bank owned lots and need to be cleaned up Overgrown and unmaintained lots create hazard for residdnts
# DATE:  10-02-2013 (WEDNESDAY)
# 4. Street Cleaning City came out to cut bushed and grass and left a mess.  Bushes and grass in street.
# 5. Right-of-Way Maintenance Issue This homeowner has not maintained the Ivy from growing into the street (Templewood rd side) and has not cleaned up the leaf debris , EVER! Templewood is now a number of feet more narrow and when it rains this area is slippery and dangerous to drive on and walk on.  This is dangerous and an eye sore.
#
# *** Worse prediction for Tree ***
#
# 1.
# 2. Overgrown trees and bushes The street is overgrown with trees and bushes that need to be cleared.  The street is growing in narrow and a hazard to oncoming cars, walkers and kids and is causing a safety hazard to our community.  I have reported this to Lee Campbell (678) 272-2038 the property manager (3) times over the last 5 wks.  I was told it would be done in 15 days and has to be cut 15 ft/in from the road.  This nice neighborhood need immediately attendtion.
# 3. Dead Tree Large dead tree in right of way between Dunwoody Club Forest and Oxford Chase.
# 4. Trees Need to be Planted Trees need to be planted along south side of North Ave. between Peachtree and 75/85 overpass.
# 5. Tree Down Tree knocked over in vehicle accident
#
# *** Worse prediction for Lane markings ***
#
# 1. Missing Bike Lane Markings The bike lanes do not have markings. Please use thermoplastic markings, or use the same markings that were used on Perimeter Center East last year.
# 2. Faded Street & Curb Painting This highly utilized intersection desperately needs street/curb repainting.  Unable to detect lanes/curbs at night w/headlights in your eyes.
# ps - the STOP line and divider line is already painted on the Peeler Road side of Independence Square, and it works VERY well.
# 4. the bike lane should be dashed before it ends The bike lane ends abruptly at the bridge of I-20. There is a 'bike lane' sign just before the lane terminates. The sign should read 'bike lane ends' and the subsequent lane should be dashed, not solid, to instruct motorists and cyclists that cyclists will be merging into the travel lane.
# 5. Repainting needed Arrows are not visible and need to be painted again.
#
# *** Worse prediction for Billing ***
#
# 1. Billing Issue Would like to discuss the garbage collection billing
# DATE:12/01/2013
# 3. BILLING ISSUE VERIFY OCCUPANCY.
# DATE:  12/2/2013
# 5. Billing Issues Need to speak with you concerning this property
#
# *** Worse prediction for Water/sewage system ***
#
# 1. Catch basin/ storm drain clogged / flooding CLOGGED STORMED DRAIN AT 3761 WALKER AVE
# ADVISED 495 @ 11:26 A.M.
# DATE:  9-27-2013 (FRIDAY)
# DATE:  10-24-2013 (THURSDAY)
# 5. Sunken Drain Traveling Southwest on 138 in the right hand lane, there is a large sunken drain. Hole or depression is 3 inches in depth.
#
# *** Worse prediction for Other ***
#
# 1.
# 2.
# 3. Beltline test Beltline test
# 4.
# http://m.seeclickfix.com
#
# *** Worse prediction for Code violation ***
#
# 1. Code Compliance Issue Two lots were cleared yesterday. Today there is a skid steer beginning to do some grading of the lots.  It appears that construction is beginning on these lots but do not see a building permit posted.
# Also, they are leaving dumpsters on the street with NO safety cones / reflectors.
# 3. PODS storage shed in yard for weeks Pods storage shed placed in yard for several weeks. Not sure if they can be stored in grass or must be in driveway? Is there a length of time these can be placed on someone's property?
# ADVISED 520 @ 9:47 A.M.
# 5. Code Compliance Issue Working on Sunday!
#
# *** Worse prediction for Parking ***
#
# 1. Box truck billboard is back As of this Sunday morning Peachtree Movers has parked another one of their trucks right back where the old one was until your Code Compliance Officer had shopping center management remove it a week or so ago
# 2. Code Compliance Issue RV parked in front if house for several months.
# 3. parking near intersection Can you install signage to inform parents of children riding the school bus not to park on Ridgeview within 100 feet of the intersection? This is dangerous as it blocks one lane of traffic and inconvenient in that the traffic signal stays red for no reason.
# 4. Code Compliance Issue Parking vehicles in front yard
# 5. Code Compliance Issue Car parked on front lawn.
#
# *** Worse prediction for Vacant/Delapidated ***
#
# 1. E C D -- Yards\Premises OR Vacant Lot 10/22/13-Tuesday: Mr. Terry Fed reports yard and premises are overgrown and in need of maintenance
# RESIDENCE HAS BEEN REPORTED SEVERAL TIMES ; ACTIONS DESPERTELY NEEDED.  ALL THE RAIN HAS IT IN HORRIBLE CONDITION
# 3. E C D - Yards/APremises OR Vacant Lot 05/08/13-Wednesday: Debra Kind reports yards/premises are in desperate need of maintenance.
# 4. E C D --Yards\Premises OR Vacant lot The house is owned by Bob Berlin. 1100 Hill Place
# 5. Yard Debris/Animal hording This yard is strewn with debris and is not maintained.  The owner is hording animals and the home is infested with German cockroaches.
#
# *** Worse prediction for Illegal activity ***
#
# 1. Graffiti  Adds to the image of blight at this intersection.
# 2. Graffiti  Graffiti on railroad bridge over southbound lanes and on garage door of maintenance building next to roadway
# 3. Graffiti graffiti on utility box
# 4. Graffiti Several houses in Camden Park neighborhood have recently had graffiti sprayed on them.  Looks like gang activity.
# 5.
#
# *** Worse prediction for Sidewalk ***
#
# 1. Sidewalk Problem Fill cracks in sidewalk behind catch basin
# 2. Sidewalk Problem A danger to runners and walkers.
# 3. Sidewalk Concern Sidewalk subsidence at stormwater drain. Tripping hazard
# 4. Metal Protrusions from the sidewalk On Glenwood, from Brownwood to Flat Shoals, on the south side of the street, there are MANY metal protrusions from the sidewalk that can trip, cut, and slice pedestrians. From West to East, there is a cut down art/bike rack, many bolts, a former bus stop where a bench and light pole were destroyed with left over remaining. These need to be removed...
# 5. Sidewalk /  " DIRT "  REQUEST THE REMOVAL OF A LARGE PILE OF DIRT LEFT ON THE SIDEWALK IN FRONT OF 220 LILLY AVE. AFTER A STREET REPAIR. ( paving )
#
# *** Worse prediction for Parks ***
#
# 1.
# 2.
# 3. Thank you to parks department! The pathway has been cleared of leaves!  Thank you!
# 4. Parks Problem cement blocks are tumbling over which could take the bridge down.  if redone, this would benefit from more cosmetically appealing materials for the wall.
# 5. Damage to Park or City Property This park has had no attention given in years.  Water is washing away the dirt making some of the equipment unsafe. Trash cans and swings are broken. Litter adorns the ground.  Please respect this area of town and address these safety concerns. This park area deserves the same amount of attention that 1st Ave Park receives.
#
# *** Worse prediction for Nuisance ***
#
# 1. Constant noise What is all of the train activity/ It is almost constant. Are they moving military equipment?
# 2. the stench of urine and feces needs cleaning Behind the waist high walls of art seem to be a private bathroom for the homeless. The smell is sickening.
# 3. Flashing LED sign in residential area Is this recently installed bright, flashing LED sign that operates 24/7 in what is essentially a residential neighborhood a Code violation?  If not, shouldn't it be?
#
# *** Worse prediction for Illegal sign ***
#
# 1. Illegal Builder Sign - Still not resolved after a month. This issue was submitted and acknowledged a month ago.  At that time it was said that the city was working with the builder and the sign would be removed the following week.  The sign has still not been removed.
# 2. Illegal signs on the right of ways There's a service station on this corner with banners and signs advertising "firewood for sale" .
# 3. Illegal signs on the right of ways From the intersection of Bass Rd. and Zebulon Rd and going toward I-475, there are about a dozen signs along Zebulon Rd.  There are 2 yard sale signs at the corner of Bass Rd/Zebulon Rd.  There's a sign near Chick-fil-A on the left.  There are 3 signs in the medium between Northway Baptist Church and Quick Med.  There's a Smiley's Flea Market sign in the medium between Capital City Bank and Robins Federal Credit Union.  There's a Romney/Ryan sign at the exit on I-475 on the left coming from the south and another Smiley's Flea Market sign near the entrance to I-475 going south.  Also, Capital City Bank has a huge banner that looks like it's on the right of way.   They are on the same side as Robins Federal Credit Union.  Please feel free to pick up any other signs that may have been placed since yesterday since these offenders work 24/7.
# 4.
# 5. Code Compliance Issue Banner sign in disrepair & violation of sign ordinance
#
# *** Worse prediction for Ditch cleaning ***
#
# 1. Ditch Needs Cleaning Out/Cutting Back the city ditch located behind my home is in need of cleaning out/cutting back.
# 2. Ditch needs cleaning REQUEST CLEANING OF THE DITCHES IN THE 700-800 BLOCK OF BARRETT AVE.
# 3. Ditch needs cleaning 09/30/13-Monday: Betty Phillips request cut back and cleaning of  ditch ROW beginning at 666 Lee Rd down to Captain Kell Dr on the right side of the street. Please remove debris from cleaning.  Ms. Phillips would like you to call her when coming out. She wants to show you something about the ditch.
# 4. Ditch needs cleaning 9/30/13-Monday: Doc Jackson request cleaning of cemented drainage canal that runs behind his property at 2278 Ballard Pl along the entire length of the canal
# ADVISED 495 @ 1:15 P.M.
#
# *** Worse prediction for Fire hydrant ***
#
# 1.
# 2. Leaking fire hydrant  Leaking fire hydrant
# 3. Leaking fire hydrant This fire hydrant has been leaking for a week.
# 4.
# 5. Fire Hydrant  Knocked Over Fire hydrant knocked over at 16th St / West Peachtree St near Artmore Hotel
#
# *** Worse prediction for Crosswalk ***
#
# 1. Crosswalk Re-Painting Needed The crosswalks at the Vermack and Womack Rd intersection are worn away and need repainting.  It is a pedestrian safety problem.
# 2. Crosswalk at the YMCA The post DeKalb county put out in the street to mark the crosswalk did not last long in the heavy traffic.
# 3. Crosswalk Crosswalk needs to be repainted.
# 4. Intersection needs light and crosswalk The Red White and Blue playground in unincorporated Cobb County needs a traffic light with pedestrian crossing signals. The parking lot for the playground is across from a busy intersection and near a church school and private day care
# Katrina Avey
#
# *** Worse prediction for Bicycle ***
#
# 1. Bike Rack Loose The bike rack nearest to the corner of Fifth and String has become loose. We believe the pavers need to be reset before it can be secured.
# 2. Water drain pothole This is horrible. Always slows down traffic because everyone merges to 1 lane to avoid potholes
# 3. Tech Square Rack Damaged The bike rack located parallel to parking space # 704 is damaged.
# 4. Bike lane potholes and gravel on 5th St. The bike lane on 5th St  at Juniper has a pothole and is full of gravel.
# 5. Tree Grates on Peachtree b/w 3rd & 5th ALL Metal Tree Grates on Peachtree b/w 3rd & 5th (West side of street only) need to be recut/replaced because they are currently restricting healthy tree growth.

# %% [markdown]
# #### Here we print out summary+description from our dataset where our model performs well.

# %%
# Where model performed very well
probsX = clf.predict_proba(X)
df_probsX = pd.DataFrame(probsX)
for ct in classes:
    if ct in df.columns:
        df_perf = pd.DataFrame({'Prob':df_probsX[list(classes).index(ct)],'SummaryDesc':data['sum_desc'], 'status':data['status'], 'Y':Y})
        df_perf = df_perf[df_perf.Y ==list(classes).index(ct)]
        
        df_perf = df_perf.sort(['Prob','SummaryDesc'],ascending=False)
        
        print "*** Best prediction for " + str(ct) +" ***"
        print " "
        j = 1
        for i in df_perf[:5]['SummaryDesc'].values:
            print str(j) + ". " + i
            j +=1
        print " "
# Out:
# *** Best prediction for Traffic ***
#
# In NW Atlanta Please?
# 2. Need speed bumps Desperately need two or three speed bumps put up due to fast traffic and the safety of my children.
# 3. TRAFFIC LIGHT TRAFFIC LIGHT GIVES EAST AVE PRIORITY, TREATS HWY 27 AS SECONDARY RD.  ALSO,ALWAYS GIVE A LEFT TURN SIGNAL ON SOUTHBOUND, CARS OR NOT, THEREFORE HINDERING TRAFFIC FOR 27 NORTHBOUND.
# 4. TRAFFIC LIGHT TRAFFIC LIGHT GIVES 120 PRIORITY, TREATS HWY 27 (4 LANE AS SECONDARY ROAD
# 5. Traffic light doesn't change for AGES During the daytime especially, the Grant St traffic light at Georgia does not change. The signal to turn from Grant onto Georgia or to go straight through Grant remains red for a very, very long time. I have waited at this light for several songs (so at least 6 or 7 minutes). Maybe a sensor is broken or the timing is off? I have on numerous occasions witnessed drivers waiting northbound on Grant running the red light because they are fed up with waiting an unreasonable amount of time... this creates an unsafe environment for other drivers and pedestrians. Who in the city do we contact?
#
# *** Best prediction for Signage ***
#
# Dr. In SW Atlanta Please?
# St. In NE Atlanta Please?
# 3. One Way Street With Insufficient Signage Curran street is one way to the north toward 14th, but between Hemphill and 14th there is little to no signage for drivers exciting local business parking which results in frequent and unchecked wrong-way drivers, especially from patrons (and staff) of Antico. The area needs better signage and active enforcement, especially by the off-duty officers there on busy nights.
# Atlanta Please?
# Atlanta Please?
#
# *** Best prediction for Dumping/debris ***
#
# 1. Debris Large pile of debris needs to be picked up
# 2. Debris / 459 / 492 pickup LARGE PILE OF LIMBS IN THE 1800 BLOCK OF WINTON AVE @ THE DEAD END OF THE STREET.
# 3. Debris / 459 / 492 pickup LARGE PILE OF LIMBS / LOGS
# 4. Debris / Attn : ( VACANT ) Inspector 493 LARGE PILE OF LIMBS IN FRONT OF VACANT PROPERTY NEXT TO 2939 RICHARD DR. ( NEEDS IMMEDIATE ATTENTION ) DEBRIS IS GETTING INTO THE CITY R/W.
# 5. Debris / 459 / 492 pickup LARGE PILE OF LIMBS
#
# *** Best prediction for Garbage ***
#
# DATE:  10-24-2013 (THURSDAY)
# DATE:  10-17-2013 (THURSDAY)
# 3. Garbage Cart / Holes in bottom Bottom's torn and the lid is off.
# 4. Garbage Cart / Broken lid BROKEN AND TORN LID. WATER GETS IN CART WHEN IT RAIN.
# 5. Garbage Cart / Broken lid BROKEN LID. REPAIR OR REPLACEMENT REQUESTED.
#
# *** Best prediction for Street cleaning ***
#
# 1. Street sweep Hinsley Ave needs sweeping .
# DATE:  11-01-2013 (FRIDAY)
# ADVISED 495 @ 12:49 P.M.
# 4. Street OR Right-of Way Cleaning Right a way on the left and right side can't see at stop sign coming off Brisbane st
# 5. Alley - needs cleaning Alley is behind 1569 Oglethorpe
#
# *** Best prediction for Utilities ***
#
# 1. Other broken power pole hovering over street with splinters sticking out.
# 2. Utility Problem Utility line down
# 3. Low Guy Wire Guy wire on pole 99 is hard to see. Needs marking
# 4. Broken utility cover in sidewalk Utility cover is busted and presents pedestrian hazard. Very easy to walk into the hole and trip, break an ankle, etc.
# 5.
#
# *** Best prediction for Street lighting ***
#
# 1. Street light on Fairgreen Trace Out Light is on the west side of Fairgreen Trace between Lake Forest and Park Forest
# 2. Street light out Street light out across fro 19 Hardwood ct
# 3. Dark intersection This intersection is very dark at night. I sometimes have trouble navigating it and I'm very familar with the area. What are the chances of having a streetlight installed here?
# 4. Street Light OUt The major street light is out.  It's entirely too dark.  This is where the kids in the neighborhood catches the school bus.
# Finally recieved a call from someone at the city---turns out GA Power handles them.
#
# *** Best prediction for Pothole/paving ***
#
# How long does one have to wait for repair to take place?
# 2. pot hole in road There is a pothole in the road, about 30 yards North of the corner of Chamblee Tucker and Henderson Mill, in the south bound lane, on right side, near the North driveway of the business.
# This hole just appeared a couple of weeks ago and seems to be getting bigger. It is very close to my driveway and I am afraid it is going to affect my driveway.
# 4. Pothole Request More than a pothole! A huge square hole cut in the street and not repaired.
# 5. Too many potholes. It's nearly impossible to avoid all of those holes and bad places in the road!
#
# *** Best prediction for Animal ***
#
# 1. Animal-Dead Pickup Request /1-total Deceased animal in the road.
# DATE:  12-05-2013 (THURSDAY)
# 3. Pet waste bags The 4 or 5 pet waste stations have been out of bags for several weeks.  I can tell a big difference in the amount of pet waste that isn't picked up along the green spaces when bags are not available for owners to clean up after their dogs.  People definitely use these bags when they're stocked.
# 4. Dead cat in road Dead cat in road
# 5. Dead Animal Pickup Emery Hwy @ Fort Hill St - Intersection
#
# *** Best prediction for Overgrowth ***
#
# 1. Clean City Owned Property 05/22/13-Emma Hill reports the lot between 3382 & 3400 Sandra Fay Drive, a clity owned lot need to be cut.  It is overgrown
# 2. Alley- needs cleaning /  cutting  REQUEST FOR ALLEY BEHIND 1231 COURTLAND AVE.  TO BE CUT OF THE OVERGROWTH AND CLEANED OF ALL THE TRASH/ GARBAGE THAT HAS BEEN DUMPED IN THE ALLEY.
# 3. overgrown grass and weeds along Blackburn Park The shoulder along Ashford Dunwoody Road beside Blackburn Park has overgrown grass and weeds which are beginning to droop out into the street.
# 4. Clean City Owned Property / " Tree " FALLEN TREE WAS DUMPED ON THE LOT. REQUEST CLEANING AND CUTTING OF THE OVERGROWTH.
# 5. Alley- needs cleaning /  cutting REQUEST FOR THE 2 ALLEYS BETWEEN EAST BUFORD RD. AND WEST BUFORD RD. TO BE CUT AND CLEANED OF THE OVERGROWTH.
#
# *** Best prediction for Tree ***
#
# ADVISED 520 @ 8:42 A.M.
# 2. Tree -Diseased and /or Dead Dead pine
# 3. Tree -Diseased and /or Dead Dead oak tree.
# 4. Tree- Bent- Leaning Limbs are covering the stop sign.
# 5.
#
# *** Best prediction for Lane markings ***
#
# 1. Missing painted crosswalks at traffic light This is a heavy traffic area with sidewalks.  There are no painted crosswalks at this traffic light.
# 2. Mis-painted lanes causing issues with traffic When Lenox road goes under NE Expressway and becomes Cheshire bridge, the lanes are mis-painted (not painted at all really). People believe that the turn lane before it goes under the bridge is 2 lanes when it is only one lane. This is because the lane marking paint has worn away. People often try to squeeze two lanes of cars in this wide one lane because they don't know any better. Please have this repainted before someone runs into someone else.
# 3. unresponsive light This traffic signal does not respond to the presence of bicycles.
# ***This week's rain made the situation extremely dangerous - could not see the road markings at all, and there are no signs!!!  It's just a matter of time before there is an accident.
# 5. lane repainting During heavy rains and at night the lanes on De Renne are very difficult to keep track of.
#
# *** Best prediction for Billing ***
#
# DATE:12/01/2013
# DATE:12/01/2013
# DATE:12/01/2013
# DATE:12/01/2013
# DATE:12/01/2013
#
# *** Best prediction for Water/sewage system ***
#
# 1. Catch basin/ storm drain clogged " 3-total " REQUEST CLEANING OF " 3 " CLOGGED STORM DRAINS CITY R/W. " 2 " DRAINS COVERED WITH DEBRIS IN FRONT OF 732 HAROLD ST, AND THE 3rd " DRAIN IS COMPLETELY COVERED WITH DEBRIS @ THE DEAD END OF THE STREET.
# 2. Catch basin/ storm drain clogged REQUEST CLEANING OF ALL STORM DRAINS ON CHAMPION DR.
# 3. Catch basin/ storm drain clogged " 3-total "  " 3 " CLOGGED STORM DRAINS ON BEDDINGFIELD AVE @ TELA PL.
# 4. Storm Drain Entirely Clogged - Water Floods Into Street The two storm water drains on Laurel Avenue in front of the listed address are almost entirely clogged with mud and debris. Weeds grow out of it. In a heavy storm, water floods between these two basins and extends almost across the street making it dangerous to drive. I took the attached picture today.
# 5. Storm Water Problem This has been getting worse over the last 2 years.  It likely goes to a stream that goes under the road about 50' away.
#
# *** Best prediction for Other ***
#
# 1. City of Milton Not Responding to Issues It appears the City of Milton is not participating in SeeClickFix, and therefore the issues being reporting may not be getting the attention they deserve.  The City of Milton has its own form for reporting problems and suggestions which can be found at:  http://www.cityofmiltonga.us/index.asp?Type=SUPERFORMS&SEC={7EBE10A4-DB26-411C-8329-A069F4A6A5C6}
# 2. individuals and animals are gaining access to private property please see pictures
# 3.
# 4.
# 5. Beltline test Beltline test
#
# *** Best prediction for Code violation ***
#
# 1.
# 2. Code Compliance Issue Are these lights legal?  They are obnoxious.
# 3. Code Compliance Issue Lazy builder put his port-o-potty in the park!
# 4. Code Compliance Issue Working on sunday
# 5. Cul-De-Sac Blocked By Fence New street is a narrow street that dead ends at fence. On the other side of the fence there is a cul-de-sac. New Street is in violation of the 2003 Fire Code section 503.2.5 because there is no way for a fire truck to turn around on the street. The city needs to use eminent domain to acquire the cul-de-sac.
#
# *** Best prediction for Parking ***
#
# 1. Parking of Travel Trailer (RV)  A Recreational Vehicle is parked on the lot at 186 Northridge Drive.  According to Section 26.08 travel trailers shall not be parked or stored on any lot or shall be permitted if parked or stored behind the front yard building line. Travel trailer needs to be removed or comply with at county ordinance. We would appreciate prompt attention to this matter.
# 2. Code Compliance Issue Parkimg in yard
# 3. cars parked in yard There are several cars at this address and some park in the front yard.
# 4. car constantly parked in curve There is a white BMW at this residence  in the Lakeshore subdivision that has been parked on the street for months. It never moves. It is parked in a curve and is a danger to those coming and going.
# 5. Excessive Parking On The Street My neighborhood, Stillwood Farms, has a tremendous amount of parking on the street. My HOA has rules against this,but,the HOA boadr has told me they can't enforce our rules due to the fact that it is not against city codes to park in the street. All of the street parking makes it very unsafe when backing out of your driveway, kids running out from behind a car or even while walking and someone could be just sitting in a car watching. I just don't like it. Can something be done about the excessive parking on both sides of the street? Thanks
#
# *** Best prediction for Vacant/Delapidated ***
#
# 1. abandoned homes Madison street is a very long street. It has several abandoned properties on it that are not occupied by anyone. Most of the homes are in bad shape and are serving as a sore eye to this community.
# 2. Unkempt and overgrown yard around abandoned house The green house on this property has been boarded up and abandoned for several years.  The yard is overgrown and the bushes have not been cut back in ages.  This lot is next to a very well-kept house and across the street from Southside community Church
# 3.
# 4. E C D - Vacant\Abandoned\Dilapidated This house has been gutted by fire 10 or so years ago, dilapidated, had homeless people living there, and is a danger & menace to my property next door at 296 Madison Street. Vacant, back door missing & overgrown shrubs & trees.
# 5. E C D Vacant Lot 05/23/13-Thursday:  Crystal Davis reports the lot next to 450 Straight St is overgrown and needs to have grass cut.
#
# *** Best prediction for Illegal activity ***
#
# 1. Graffiti in parking lot walls Various graffiti on walls in parking lot below gas station off of Beverly.  Can Midtown Green assist?
# 2. graffiti Graffiti on utility boxes
# 3. Crime/Safety Issues There have been numerous vehicle break-ins in the subdvision. More street lights and more police presence at night may detere this crime. Also, speed humps would make this street safer since thru traffic is constantly speeding through the subdvision. Northbridge Dr is a long hilly street and high rates of speed are observed quite frequently.
# 4.
# 30338
#
# *** Best prediction for Sidewalk ***
#
# 1.
# 2. Metal sticking out of sidewalk This could really hurt someone, it's sticking out about 2.5 inches.
# 3.
# 4. Sidewalk Please make sure corners are being swept or blown out regularly and that weeds are being killed.
# 5. Missing Sidewalk Sidewalk was taken up several months ago and has not been replaced.  This  issue creates a huge safety problem, esepcially at night, for the elderly and children as there is a substanual drop off.
#
# *** Best prediction for Parks ***
#
# 1. Parks Problem Scary
# 2.
# 3. Parks Problem on path around Murphey Candler Park.
# 4. Fence Down along Path in Blackburn The downed fence along the Path in Blackburn around the soccer fields is a hazard as well as an embarrassing situation. When I took my guests for a walk around the park, they said "someone needs to maintain this park better."
# 5. Parks Problem bench wood warped and has splinters
#
# *** Best prediction for Nuisance ***
#
# 1. Constant noise What is all of the train activity/ It is almost constant. Are they moving military equipment?
# 2. the stench of urine and feces needs cleaning Behind the waist high walls of art seem to be a private bathroom for the homeless. The smell is sickening.
# 3. Flashing LED sign in residential area Is this recently installed bright, flashing LED sign that operates 24/7 in what is essentially a residential neighborhood a Code violation?  If not, shouldn't it be?
#
# *** Best prediction for Illegal sign ***
#
# 1. Illegal "Bike Route" Sign Installed on Mt. Vernon This segment of Mt. Vernon was designated & approved by City Council to have Bike Lanes. The signs at each end state "Bike Route.". This signage provides no legal protection of the cyclists for the bike lane. For example, driving in it, parking in it, etc. Instead (& especially since there are no painted bike lane markings, either), the Dunwoody Law Enforcement would be unable to ticket a motor vehicle driver in violating these legal protections of a bike lane. See the proper MUTCD Bike Lane Signage on Roberts Drive for the legal examples. This needs to be fixed at the highest priority, for the safety of bicyclists.
# 2. Illegal Signs Over the past couple of weeks there has been a proliferation of illegal signage on Brookhaven streets.  Specifically, Roots & Brews, Brookhaven Chili Cook-Off, Brookhaven Arts Festival, several businesses and a local doctor have illegal signage cluttering up roadway right of ways.  Is it possible for this illegal signage to be removed?  This is not a line of sight issue, it is a clutter issue.
# Thank you!
# 4. Illegal signs in ROW Several illegal "bandit" signs on wire supports have been placed in the ROW here advertising "help wanted" among other things. These are blue and white and so close to the street that you can reach out and touch them from a vehicle. Illegal per OCGA 32-6-51.
# 5. Illegal Signs in ROW Several illegal "bandit" signs on wire supports have been placed in the ROW here advertising "help wanted" among other things. These are blue and white and so close to the street that you can reach out and touch them from a vehicle. Illegal per OCGA 32-6-51.
#
# *** Best prediction for Ditch cleaning ***
#
# DATE:  8-15-2013 (THURSDAY)
# 2. Ditch needs Cleaning 10/21/13-Monday:Bannie  Edwards reports a drainage pond to the side of the property is owned by the city and needs cleaning.
# DATE:  6-20-2013 (THURSDAY)
# DATE:  11-07-2013 (THURSDAY)
# DATE:  8-02-2013 (FRIDAY)
#
# *** Best prediction for Fire hydrant ***
#
# 1. Fire Hydrant Leaking Fire Hydrant Leaking Water
# 2. Seaboard Waterfalls Sorry this is not a pothole...but a fire hydrant that has been spewing water for over a week that I know of and since I have returned from Europe...so I don't know how long this situation has been wasting water.  I surmise that the valve may be broke but do not understand how the water works thinks by placing a rag above the hydrant will slow the water down to any degree to make a difference...and how this can go on for more than three days without pulling the hydrant and at least mounting a plate to stop the run off.  Please help...can we as a city really be this apathetic or ignorant of our resources?  Lastly the video was the wrong format and horrible...so sorry I could not submit  but I'm sure your camera team would get much better footage...  =-)
# 3. Other Fire hydrant leaking
# 4. Fire Hydrant  Tree limbs have completely covered this fire hydrant. Closest house is 1958 Slate Road. I had to move the limbs to see the hydrant in the photo.
# 5. Fire hydrant Fire hydrant flooding the street
#
# *** Best prediction for Crosswalk ***
#
# 1. Crosswalk designation request We are residents of Haven Brook, a neighborhood at the intersection of Osborne road and Haven Brook Lane. Our daughter attends school at Ashford Park Elementary and is in 4th grade. Her bus stop is located across Osborne road, therefore she has to cross Osborne to get to the sidewalk in order to walk to her bus stop. Osborn is a very busy road, hilly and curvy, and people drive very fast and appear quickly around bends. We would like to have a crosswalk created to for this high traffic road in an effort to maintain a semblance of safety for our family and others in our area. Thank you.
# 2.
# 3.  brick crosswalks need repair All the nice brick crosswalks along ponce through the city need to be repaired. They are very dangerous for strollers and people that use rollator walkers or wheelchairs. They are a fall hazard.
# 4. Crosswalk The crosswalk at 4th & Juniper wasn't repainted after the street was repaved. There is one at 4th & Piedmont.
# 5. Crosswalks at Cambridge Square The posts DeKalb county put in Ashford Dunwoody to mark the crosswalks at Cambridge Sq. didn't last long in the heavy traffic. There's another crosswalk at Cambridge on Johnson Ferry near Waddeston that also needs marking.
#
# *** Best prediction for Bicycle ***
#
# 1. Serious safety hazard for bicyclists from Windward Please view the video that I shot, it explains the issue very well. There is no safe way to access the Alpharetta Greenway when traveling westbound on Webb Bridge road. I posted the video on the city facebook page. I don't seem to be able to include a link to the video here.The video is on youtube, I can email a link if you like.
# 2. open road seam There is a open seam running parallel to the road on the right side near the bridge. The seam is closest to the part of the road where cyclists ride and presents a problem where ones tires can get wedged into the road.
# 3. bicycle hazards- bad streets Pot holes, really need a bike lane on campbellton in between stanton and delowe roads, sidwalks in bad shape/ not safe streets in bad shape. need to fully repave delowe dr. between 166 and campbellton
# 4. bicycle hazards water leak from unknown source causes red to be very wet, sometimes icy.
# 5. bicycle hazards water drain grate is parallel to road.  Very dangerous to bikers.

# %% [markdown]
# ### Summary

# %% [raw]
# Since potholes and garbage makes-up a huge percentage of the dataset, they have the highest probabilities of been predicted correctly. More data is need on the remaining classes in order to improve the accuracy of the classifier.
